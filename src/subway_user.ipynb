# %%
import pandas as pd

data_user = pd.read_csv("../../data/team_project_eda/지하철 호선별 역별 시간대별 승하차 인원 정보.csv", encoding = 'euc-kr')

# %%
#data_user.drop(columns = "작업일자", inplace = True)

data_user.rename(columns = {"04시-05시 승차인원": "05시 승차", "05시-06시 승차인원": "06시 승차", "06시-07시 승차인원": "07시 승차",\
    "07시-08시 승차인원": "08시 승차", "08시-09시 승차인원": "09시 승차", "09시-10시 승차인원": "10시 승차", "10시-11시 승차인원": "11시 승차",\
    "11시-12시 승차인원": "12시 승차", "12시-13시 승차인원": "13시 승차", "13시-14시 승차인원": "14시 승차", "14시-15시 승차인원": "15시 승차",\
    "15시-16시 승차인원": "16시 승차", "16시-17시 승차인원": "17시 승차", "17시-18시 승차인원": "18시 승차", "18시-19시 승차인원": "19시 승차",\
    "19시-20시 승차인원": "20시 승차", "20시-21시 승차인원": "21시 승차", "21시-22시 승차인원": "22시 승차", "22시-23시 승차인원": "23시 승차",\
    "23시-24시 승차인원": "24시 승차", "00시-01시 승차인원": "01시 승차", "01시-02시 승차인원": "02시 승차", "02시-03시 승차인원": "03시 승차",\
    "03시-04시 승차인원": "04시 승차"}, inplace = True)

data_user.rename(columns = {"04시-05시 하차인원": "05시 하차", "05시-06시 하차인원": "06시 하차", "06시-07시 하차인원": "07시 하차",\
    "07시-08시 하차인원": "08시 하차", "08시-09시 하차인원": "09시 하차", "09시-10시 하차인원": "10시 하차", "10시-11시 하차인원": "11시 하차",\
    "11시-12시 하차인원": "12시 하차", "12시-13시 하차인원": "13시 하차", "13시-14시 하차인원": "14시 하차", "14시-15시 하차인원": "15시 하차",\
    "15시-16시 하차인원": "16시 하차", "16시-17시 하차인원": "17시 하차", "17시-18시 하차인원": "18시 하차", "18시-19시 하차인원": "19시 하차",\
    "19시-20시 하차인원": "20시 하차", "20시-21시 하차인원": "21시 하차", "21시-22시 하차인원": "22시 하차", "22시-23시 하차인원": "23시 하차",\
    "23시-24시 하차인원": "24시 하차", "00시-01시 하차인원": "01시 하차", "01시-02시 하차인원": "02시 하차", "02시-03시 하차인원": "03시 하차",\
    "03시-04시 하차인원": "04시 하차"}, inplace = True)

# %%
data_user.drop(columns = {"24시 승차", "01시 승차", "02시 승차", "03시 승차", "04시 승차", "05시 승차",\
    "24시 하차", "01시 하차", "02시 하차", "03시 하차", "04시 하차", "05시 하차", "작업일자"}, inplace = True)

data_user
# Out:
#           사용월  호선명 지하철역  06시 승차  06시 하차  07시 승차  07시 하차  08시 승차  08시 하차  \
# 0      202505  1호선  동대문   11411    1920    9784    7385   16724   13140
# 1      202505  1호선  동묘앞    2859     986    4018    5686    8874   11760
# 2      202505  1호선  서울역   10783   10374   28788   65184   90177  127458
# 3      202505  1호선   시청    1938    5755    3754   27708    7542   74917
# 4      202505  1호선  신설동    9502    2362   10403    9078   22203   25943
# ...       ...  ...  ...     ...     ...     ...     ...     ...     ...
# 74272  201501  중앙선  운길산     177      56     642     403    1292     675
# 74273  201501  중앙선   원덕     292       4     415      46     537     248
# 74274  201501  중앙선   중랑    4929     424    8539    2084   22160    3027
# 74275  201501  중앙선   팔당     161      50     368     149    1227     523
# 74276  201501  중앙선   회기   10929    3067   23317   10430   65043   24473
#
#        09시 승차  ...  19시 승차  19시 하차  20시 승차  20시 하차  21시 승차  21시 하차  22시 승차  \
# 0       22729  ...   25641   23523   19867   22819   17606   16985   15411
# 1       14014  ...   25464   13959   13532    9798    6943    6785    5587
# 2      151470  ...  252289  173736  144704  119129  106540   88200  111385
# 3       10220  ...  156643   26202   62998   13978   58654    9328   50245
# 4       32851  ...   51467   31725   21232   23013   15014   17361   13569
# ...       ...  ...     ...     ...     ...     ...     ...     ...     ...
# 74272    1479  ...    2304    1218    1332    1457    1002     769     942
# 74273     823  ...     563     721     175     714     156     612      53
# 74274   25792  ...    8399   19547    6449   21424    4652   14362    3849
# 74275     910  ...    1617     822     845     749     492     320     420
# 74276   85473  ...   59218   76039   38996   81870   33754   53481   34364
#
#        22시 하차  23시 승차  23시 하차
# 0       15450   12070   15180
# 1        6811    4091    6995
# 2       82681   75904   62690
# 3        8165   30412    5957
# 4       16853    9296   14996
# ...       ...     ...     ...
# 74272     760     270     775
# 74273     404      71     339
# 74274   11678    3062   11060
# 74275     319     309     339
# 74276   50706   31606   49658
#
# [74277 rows x 39 columns]

# %%
data_user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74277 entries, 0 to 74276
# Data columns (total 39 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   사용월     74277 non-null  int64
#  1   호선명     74277 non-null  object
#  2   지하철역    74277 non-null  object
#  3   06시 승차  74277 non-null  int64
#  4   06시 하차  74277 non-null  int64
#  5   07시 승차  74277 non-null  int64
#  6   07시 하차  74277 non-null  int64
#  7   08시 승차  74277 non-null  int64
#  8   08시 하차  74277 non-null  int64
#  9   09시 승차  74277 non-null  int64
#  10  09시 하차  74277 non-null  int64
#  11  10시 승차  74277 non-null  int64
#  12  10시 하차  74277 non-null  int64
#  13  11시 승차  74277 non-null  int64
#  14  11시 하차  74277 non-null  int64
#  15  12시 승차  74277 non-null  int64
#  16  12시 하차  74277 non-null  int64
#  17  13시 승차  74277 non-null  int64
#  18  13시 하차  74277 non-null  int64
#  19  14시 승차  74277 non-null  int64
#  20  14시 하차  74277 non-null  int64
#  21  15시 승차  74277 non-null  int64
#  22  15시 하차  74277 non-null  int64
#  23  16시 승차  74277 non-null  int64
#  24  16시 하차  74277 non-null  int64
#  25  17시 승차  74277 non-null  int64
#  26  17시 하차  74277 non-null  int64
#  27  18시 승차  74277 non-null  int64
#  28  18시 하차  74277 non-null  int64
#  29  19시 승차  74277 non-null  int64
#  30  19시 하차  74277 non-null  int64
#  31  20시 승차  74277 non-null  int64
#  32  20시 하차  74277 non-null  int64
#  33  21시 승차  74277 non-null  int64
#  34  21시 하차  74277 non-null  int64
#  35  22시 승차  74277 non-null  int64
#  36  22시 하차  74277 non-null  int64
#  37  23시 승차  74277 non-null  int64
#  38  23시 하차  74277 non-null  int64
# dtypes: int64(37), object(2)
# memory usage: 22.1+ MB

# %%
# 역 이용객은 월평균으로 접근

df_line1 = data_user.loc[data_user["호선명"] == "1호선"]

df_line1 = df_line1.loc[df_line1["사용월"] >= 201901]
df_line1 = df_line1.loc[df_line1["사용월"] <= 202312]

df_line1 = df_line1.sort_values(by = ["지하철역", "사용월"], ascending = [True, False])
df_line1.reset_index(drop = True, inplace = True)

df_line2 = data_user.loc[data_user["호선명"] == "2호선"]

df_line2 = df_line2.loc[df_line2["사용월"] >= 201901]
df_line2 = df_line2.loc[df_line2["사용월"] <= 202312]

df_line2 = df_line2.sort_values(by = ["지하철역", "사용월"], ascending = [True, False])
df_line2.reset_index(drop = True, inplace = True)

df_line3 = data_user.loc[data_user["호선명"] == "3호선"]

df_line3 = df_line3.loc[df_line3["사용월"] >= 201901]
df_line3 = df_line3.loc[df_line3["사용월"] <= 202312]

df_line3 = df_line3.sort_values(by = ["지하철역", "사용월"], ascending = [True, False])
df_line3.reset_index(drop = True, inplace = True)

df_line4 = data_user.loc[data_user["호선명"] == "4호선"]

df_line4 = df_line4.loc[df_line4["사용월"] >= 201901]
df_line4 = df_line4.loc[df_line4["사용월"] <= 202312]

df_line4 = df_line4.sort_values(by = ["지하철역", "사용월"], ascending = [True, False])
df_line4.reset_index(drop = True, inplace = True)

df_line5 = data_user.loc[data_user["호선명"] == "5호선"]

df_line5 = df_line5.loc[df_line5["사용월"] >= 201901]
df_line5 = df_line5.loc[df_line5["사용월"] <= 202312]

df_line5 = df_line5.sort_values(by = ["지하철역", "사용월"], ascending = [True, False])
df_line5.reset_index(drop = True, inplace = True)

df_line6 = data_user.loc[data_user["호선명"] == "6호선"]

df_line6 = df_line6.loc[df_line6["사용월"] >= 201901]
df_line6 = df_line6.loc[df_line6["사용월"] <= 202312]

df_line6 = df_line6.sort_values(by = ["지하철역", "사용월"], ascending = [True, False])
df_line6.reset_index(drop = True, inplace = True)

df_line7 = data_user.loc[data_user["호선명"] == "7호선"]

df_line7 = df_line7.loc[df_line7["사용월"] >= 201901]
df_line7 = df_line7.loc[df_line7["사용월"] <= 202312]

df_line7 = df_line7.sort_values(by = ["지하철역", "사용월"], ascending = [True, False])
df_line7.reset_index(drop = True, inplace = True)

df_line8 = data_user.loc[data_user["호선명"] == "8호선"]

df_line8 = df_line8.loc[df_line8["사용월"] >= 201901]
df_line8 = df_line8.loc[df_line8["사용월"] <= 202312]

df_line8 = df_line8.sort_values(by = ["지하철역", "사용월"], ascending = [True, False])
df_line8.reset_index(drop = True, inplace = True)

# %%
df_line_all = pd.concat([df_line1, df_line2, df_line3, df_line4, df_line5, df_line6, df_line7, df_line8], ignore_index = True)

df_line_all
# Out:
#           사용월  호선명      지하철역  06시 승차  06시 하차  07시 승차  07시 하차  08시 승차  08시 하차  \
# 0      202312  1호선       동대문   11117    2085    8840    5685   14001    9896
# 1      202311  1호선       동대문   11780    2144    9684    6468   15581   11446
# 2      202310  1호선       동대문   11493    2221    9618    6755   14951   12017
# 3      202309  1호선       동대문   10733    1973    9065    6382   14371   11453
# 4      202308  1호선       동대문   10772    1896    8832    6226   13629   11392
# ...       ...  ...       ...     ...     ...     ...     ...     ...     ...
# 16738  201905  8호선  천호(풍납토성)   12189    2102   21127   13775   54277   21307
# 16739  201904  8호선  천호(풍납토성)   11359    1926   20770   13615   56495   20905
# 16740  201903  8호선  천호(풍납토성)   10944    1858   19315   13639   53160   20203
# 16741  201902  8호선  천호(풍납토성)    8466    1405   15167   10755   40484   15385
# 16742  201901  8호선  천호(풍납토성)   10085    1762   18428   12464   50030   19062
#
#        09시 승차  ...  19시 승차  19시 하차  20시 승차  20시 하차  21시 승차  21시 하차  22시 승차  \
# 0       19766  ...   24101   22687   17016   19837   14983   14699   13598
# 1       21234  ...   23353   22027   16063   21224   14337   14402   13253
# 2       20657  ...   25680   22333   17817   21418   15062   14927   13799
# 3       19562  ...   25383   23480   18716   21595   16092   15948   15090
# 4       18670  ...   22855   20604   16345   18898   13922   13887   12373
# ...       ...  ...     ...     ...     ...     ...     ...     ...     ...
# 16738   76166  ...   45160   84850   31401   70517   26204   39928   20273
# 16739   77404  ...   43980   84200   29830   70712   24857   38998   19273
# 16740   74315  ...   45145   82100   30280   69453   25750   39163   19800
# 16741   59418  ...   39144   68603   26015   60305   22202   33052   17636
# 16742   76622  ...   46467   83145   30024   71324   24934   38051   19934
#
#        22시 하차  23시 승차  23시 하차
# 0       13701   10911   13145
# 1       13060   10008   12374
# 2       13295   10430   12184
# 3       14053   11578   12152
# 4       12762    9527   11158
# ...       ...     ...     ...
# 16738   37342   16949   33152
# 16739   36871   16082   32586
# 16740   36348   17070   31900
# 16741   30541   15157   27176
# 16742   35084   17645   31403
#
# [16743 rows x 39 columns]

# %%
df_2023 = df_line_all.loc[df_line_all["사용월"] >= 202301]
df_2023 = df_2023.loc[df_line_all["사용월"] <= 202312]

df_2023.reset_index(drop = True, inplace = True)

df_2023
# Out:
#          사용월  호선명      지하철역  06시 승차  06시 하차  07시 승차  07시 하차  08시 승차  08시 하차  \
# 0     202312  1호선       동대문   11117    2085    8840    5685   14001    9896
# 1     202311  1호선       동대문   11780    2144    9684    6468   15581   11446
# 2     202310  1호선       동대문   11493    2221    9618    6755   14951   12017
# 3     202309  1호선       동대문   10733    1973    9065    6382   14371   11453
# 4     202308  1호선       동대문   10772    1896    8832    6226   13629   11392
# ...      ...  ...       ...     ...     ...     ...     ...     ...     ...
# 3314  202305  8호선  천호(풍납토성)   11094    1760   17373   12717   41918   15142
# 3315  202304  8호선  천호(풍납토성)   10658    1698   16992   12302   41491   14532
# 3316  202303  8호선  천호(풍납토성)   10989    1597   17784   12681   45047   15341
# 3317  202302  8호선  천호(풍납토성)    9302    1299   15196   10993   37079   13006
# 3318  202301  8호선  천호(풍납토성)    8915    1360   14917   10262   36383   13054
#
#       09시 승차  ...  19시 승차  19시 하차  20시 승차  20시 하차  21시 승차  21시 하차  22시 승차  \
# 0      19766  ...   24101   22687   17016   19837   14983   14699   13598
# 1      21234  ...   23353   22027   16063   21224   14337   14402   13253
# 2      20657  ...   25680   22333   17817   21418   15062   14927   13799
# 3      19562  ...   25383   23480   18716   21595   16092   15948   15090
# 4      18670  ...   22855   20604   16345   18898   13922   13887   12373
# ...      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 3314   56947  ...   30789   67147   20675   45665   17160   28264   13200
# 3315   57034  ...   30907   67401   20277   45659   17069   27986   13360
# 3316   61133  ...   32884   72540   21437   49916   17592   29255   13713
# 3317   54260  ...   29993   65858   19222   46011   16077   26423   12549
# 3318   52757  ...   29497   63584   18981   44705   15877   25994   12600
#
#       22시 하차  23시 승차  23시 하차
# 0      13701   10911   13145
# 1      13060   10008   12374
# 2      13295   10430   12184
# 3      14053   11578   12152
# 4      12762    9527   11158
# ...      ...     ...     ...
# 3314   25141    9672   21729
# 3315   24868    9753   21399
# 3316   25877   10077   22360
# 3317   23064    9764   20018
# 3318   23176    9610   19061
#
# [3319 rows x 39 columns]

# %%
df_2022 = df_line_all.loc[df_line_all["사용월"] >= 202201]
df_2022 = df_2022.loc[df_line_all["사용월"] <= 202212]

df_2022.reset_index(drop = True, inplace = True)

df_2022
# Out:
#          사용월  호선명      지하철역  06시 승차  06시 하차  07시 승차  07시 하차  08시 승차  08시 하차  \
# 0     202212  1호선       동대문   10546    1950    8505    5809   13440   10380
# 1     202211  1호선       동대문   10942    1871    8782    6391   14368   11493
# 2     202210  1호선       동대문   11017    1926    9398    6871   14707   11779
# 3     202209  1호선       동대문   10195    1888    8595    6719   14334   11657
# 4     202208  1호선       동대문    9859    1842    8375    6305   13390   11046
# ...      ...  ...       ...     ...     ...     ...     ...     ...     ...
# 3357  202205  8호선  천호(풍납토성)   11266    1764   17416   11298   40408   14353
# 3358  202204  8호선  천호(풍납토성)   10735    1697   16317   10568   38187   12764
# 3359  202203  8호선  천호(풍납토성)   10042    1610   14886    9673   35895   12036
# 3360  202202  8호선  천호(풍납토성)    8434    1277   13100    8248   30362   10475
# 3361  202201  8호선  천호(풍납토성)    9573    1362   14608    9207   35460   12244
#
#       09시 승차  ...  19시 승차  19시 하차  20시 승차  20시 하차  21시 승차  21시 하차  22시 승차  \
# 0      18824  ...   23840   20880   17073   19232   14042   13375   13368
# 1      20005  ...   23037   20137   16089   19091   13946   12598   12552
# 2      19432  ...   24942   21033   17122   19705   14662   13926   13377
# 3      18660  ...   23383   20149   17042   18731   13817   12741   12641
# 4      17632  ...   22042   18224   15665   16396   12774   11721   11441
# ...      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 3357   58073  ...   30873   67964   20610   49016   17535   28056   13514
# 3358   54726  ...   28625   65549   18808   44673   15926   26126   12268
# 3359   50157  ...   25931   60278   17094   39955   14127   22664   11166
# 3360   44681  ...   23538   53428   15085   35275   14349   19912   13271
# 3361   52748  ...   27577   63081   17317   41148   18018   23270   17203
#
#       22시 하차  23시 승차  23시 하차
# 0      11520   10411   11303
# 1      10865    9395    9671
# 2      11666   10591   10596
# 3      10923   10337    9684
# 4      10406    9117    9518
# ...      ...     ...     ...
# 3357   24860   10865   22667
# 3358   23143    9364   19601
# 3359   19791    8512   16948
# 3360   22658    6472   14734
# 3361   30628    5984   16216
#
# [3362 rows x 39 columns]

# %%
df_year_data1 = [202312, 202212, 202112, 202012, 201912]
df_year_title = [2023, 2022, 2021, 2020, 2019]

# %%
df_station = df_2023.loc[df_2023["사용월"] == 202312]

df_station.reset_index(drop = True, inplace = True)

#df_station = df_2023.loc[df_2023["지하철역"] == "동대문"]

df_station
# Out:
#         사용월  호선명      지하철역  06시 승차  06시 하차  07시 승차  07시 하차  08시 승차  08시 하차  \
# 0    202312  1호선       동대문   11117    2085    8840    5685   14001    9896
# 1    202312  1호선       동묘앞    2785     956    3330    4326    7069    7749
# 2    202312  1호선       서울역    7812    8436   12190   50415   37075  105313
# 3    202312  1호선        시청    2208    4356    3731   21903    7341   63969
# 4    202312  1호선       신설동    8628    1943    9192    8105   19443   20328
# ..      ...  ...       ...     ...     ...     ...     ...     ...     ...
# 273  202312  8호선        신흥    3753     415    6926    2250   15725    3323
# 274  202312  8호선        암사   14422     837   27047    4764   74252    7982
# 275  202312  8호선  잠실(송파구청)    1461    2879    4475   10114    8823   29195
# 276  202312  8호선        장지    5529    2785   17911   11567   42424   25235
# 277  202312  8호선  천호(풍납토성)    9558    1727   15601   12326   38456   14034
#
#      09시 승차  ...  19시 승차  19시 하차  20시 승차  20시 하차  21시 승차  21시 하차  22시 승차  \
# 0     19766  ...   24101   22687   17016   19837   14983   14699   13598
# 1     11703  ...   17921   11186    8448    8487    5722    6488    4445
# 2     68020  ...  214755  101935  119593   74342   89409   54361   91804
# 3      9896  ...  154694   36383   69657   18213   67783   11988   63805
# 4     29568  ...   49706   29737   19646   21695   14492   15767   12236
# ..      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 273   21774  ...    8846   19784    5197   15367    4372   10256    3417
# 274   98989  ...   22772   67640   13286   53482   10448   33380    8361
# 275   12334  ...   75906   52461   49285   27104   48973   15335   49743
# 276   53146  ...   48682   49077   25425   32384   23403   21205   18481
# 277   54894  ...   33671   67076   20386   44541   17745   28626   13718
#
#      22시 하차  23시 승차  23시 하차
# 0     13701   10911   13145
# 1      7004    3328    7205
# 2     51756   61927   34379
# 3     10626   42298    8058
# 4     15491    8866   13666
# ..      ...     ...     ...
# 273    9272    2418    8533
# 274   29878    5791   31508
# 275   11291   36495    8620
# 276   18949   10207   18591
# 277   25961   10336   23309
#
# [278 rows x 39 columns]

# %%
df_2023_station = df_2023.loc[df_2023["사용월"] == 202312]

#df_2023_station = df_2023.loc[df_2023["지하철역"] == "동대문"]

df_2023_station.reset_index(drop = True, inplace = True)

station_name = df_2023_station.loc[0,"지하철역"]

station_name
# Out:
# '동대문'

# %%
#역 정보 모으기

df_2023_station_title = df_2023.loc[df_2023["사용월"] == 202312]

df_2023_line = ["1호선", "2호선", "3호선", "4호선", "5호선", "6호선", "7호선", "8호선"]

df_2023_station_title = df_2023_station_title.loc[df_2023["호선명"] == df_2023_line[1]]

#df_2023_station = df_2023_station.loc[df_2023["지하철역"] == "동대문"]

df_2023_station_title.reset_index(drop=True, inplace=True)

df_2023_station_title

#len(de_2023_station)
# Out:
#        사용월  호선명            지하철역  06시 승차  06시 하차  07시 승차  07시 하차  08시 승차  \
# 0   202312  2호선              강남   10077   10718   18160   53856   36702
# 1   202312  2호선      강변(동서울터미널)    8316    1994   25176   19082   70058
# 2   202312  2호선            건대입구   15464    1959   20985   14610   49461
# 3   202312  2호선      교대(법원.검찰청)    2343    6558   10316   22656   22110
# 4   202312  2호선         구로디지털단지   36799    5040   48809   19298  131619
# 5   202312  2호선        구의(광진구청)   13033    1495   24625   23443   62655
# 6   202312  2호선        낙성대(강감찬)   11171    2208   24885   10354   75862
# 7   202312  2호선              당산    6373    2967   15687   11967   40594
# 8   202312  2호선        대림(구로구청)   32398    3056   27546    9570   61788
# 9   202312  2호선             도림천     420     323    1111     864    2891
# 10  202312  2호선  동대문역사문화공원(DDP)    5222    1124    4033    8301    6894
# 11  202312  2호선              뚝섬    2948    2320    7579   15944   16429
# 12  202312  2호선              문래    3821    2245   12792   10353   40202
# 13  202312  2호선              방배    2426    2601    8364   11911   19722
# 14  202312  2호선              봉천   14844    1879   26943    7627   75846
# 15  202312  2호선              사당   11704    4205   26210   32061   71615
# 16  202312  2호선        삼성(무역센터)    4565    5282    6487   40806   13489
# 17  202312  2호선            상왕십리    5657     830   12622    5583   37494
# 18  202312  2호선     서울대입구(관악구청)   27064    2643   40832   13784  115568
# 19  202312  2호선              서초    1947    4153    8583   21534   16868
# 20  202312  2호선              선릉    4947    6003   10959   40265   19530
# 21  202312  2호선              성수    5786    3390    8980   31817   20550
# 22  202312  2호선              시청     832    1697    2266   16645    5263
# 23  202312  2호선              신답    1097     129    1708     600    5485
# 24  202312  2호선              신당    6218    1188   10878    7884   25597
# 25  202312  2호선             신대방   23101    1918   31899    9429   83152
# 26  202312  2호선             신도림   34910    4670   50232   19270  126498
# 27  202312  2호선              신림   36317    3942   64151   16573  168672
# 28  202312  2호선             신설동    1162     290    1370    1875    4329
# 29  202312  2호선           신정네거리    8246    1038   16591    2662   46342
# 30  202312  2호선              신촌    7856    2891   14275   14331   34680
# 31  202312  2호선              아현    4821     796   10025    4173   27618
# 32  202312  2호선            양천구청    4472     973   10675    2359   31034
# 33  202312  2호선              역삼    3628    6224    8911   39742   14489
# 34  202312  2호선           영등포구청    5128    3270   11288   14228   36248
# 35  202312  2호선       왕십리(성동구청)    6482     908    9478    7969   22826
# 36  202312  2호선              용답    2102     366    2959    1105    7410
# 37  202312  2호선       용두(동대문구청)    1162     156    1801     891    5007
# 38  202312  2호선           을지로3가    1335    1815    2782   18834    6323
# 39  202312  2호선           을지로4가     894    1092    1961   13022    4993
# 40  202312  2호선           을지로입구    2461    2722    4386   27074   10290
# 41  202312  2호선              이대    3682     966    8687    6209   25843
# 42  202312  2호선        잠실(송파구청)   12952    4902   48144   32495  111877
# 43  202312  2호선            잠실나루    3194    2907   11370   16087   33886
# 44  202312  2호선            잠실새내    5757    1083   16425    8314   52051
# 45  202312  2호선           종합운동장    1452     948    5695    8332   14837
# 46  202312  2호선      충정로(경기대입구)    3029     997    6181    6086   15118
# 47  202312  2호선             한양대    1266     567    2370    6599    5035
# 48  202312  2호선              합정   10924    2489   17735   12776   40952
# 49  202312  2호선            홍대입구   30969    3804   32093   17644   58680
#
#     08시 하차  09시 승차  ...  19시 승차  19시 하차  20시 승차  20시 하차  21시 승차  21시 하차  \
# 0   133015   58885  ...  295278  189811  200483  110805  161575   61660
# 1    21276  107811  ...   60571  105525   42454   75080   32658   55641
# 2    22460   89622  ...   90919  156090   69703  106891   71960   68295
# 3    47066   34354  ...  121011   77891   59183   41640   53974   26400
# 4    74242  176836  ...  188913  156345   94371  126348   63679   85939
# 5    15923  109941  ...   45612   92509   25028   65227   19892   45664
# 6    18274  117304  ...   49105   92987   28207   80314   22657   54267
# 7    25303   51179  ...   53057   67630   24337   46487   19840   32447
# 8    20531   91367  ...   48902   63985   26449   49182   19623   38925
# 9     3386    3444  ...    3177    2917    1533    2273     737    1777
# 10   20262   12108  ...   49801   38465   33570   33966   26334   25826
# 11   38228   24900  ...  126795   50491   68181   27920   48579   15486
# 12   34824   48133  ...  102158   60097   39520   40763   29748   23176
# 13   23875   29049  ...   56717   36487   26595   24494   23141   17111
# 14   12551  113637  ...   32700   80291   20089   69327   16810   45275
# 15   41460   92510  ...   96252  179093   73362  118869   73914   72680
# 16  120287   17920  ...  298236   76409  161427   38301  137548   20797
# 17   11535   63165  ...   26991   52526   18717   34548   12148   24985
# 18   26043  159468  ...   90261  159414   53011  132035   46455   85232
# 19   49976   26332  ...   86628   29690   44246   18503   33157   12080
# 20  108225   32554  ...  262918   64823  134559   38018   92240   24087
# 21   65573   29369  ...  241758   85528  124944   49311   97975   24462
# 22   64223    8250  ...  161292   29222   62871   15150   54461   10456
# 23     815   10656  ...    2178    8929    1051    6164     709    3508
# 24   14794   46336  ...   32370   57107   22789   36541   18764   23937
# 25   14116  125906  ...   33210   87157   20528   75149   16199   54808
# 26   41873  139519  ...  123275  166002   73083  118674   63899   74752
# 27   25109  250796  ...   81192  201965   53915  179682   46045  121499
# 28    4747    7719  ...   13772    7191    4793    5148    3348    4081
# 29    4233   43868  ...   12199   45705    7179   34064    5749   20592
# 30   32742   50720  ...   98489  119318   70766   79348   75664   48597
# 31   10908   40656  ...   19652   32727   12213   23689    9071   17876
# 32    4412   28571  ...    8887   28011    4007   23068    2726   14878
# 33  135228   25209  ...  238296   66506  135602   39194   85454   23408
# 34   35442   45125  ...   95000   55329   36292   36695   29540   23268
# 35   11907   41777  ...   35953   56382   24063   34080   24235   22534
# 36    1730   13382  ...    4214   10669    2568    7071    1801    5311
# 37    2402    9262  ...    5474    8547    2691    5254    2117    3460
# 38   67072   11804  ...  128848   44725   58174   26891   47487   17217
# 39   33496   10025  ...   63226   18764   27983   12330   18220    9304
# 40  117184   17234  ...  279142   94162  147973   54907  153136   34733
# 41   12466   35645  ...   38350   45285   24308   32652   20873   23486
# 42   73695  155188  ...  266447  256515  196902  165501  209945  110534
# 43   21400   45001  ...   29315   37578   13862   27054   10658   18723
# 44   15468   78758  ...   46234   89871   33754   61760   30525   39779
# 45   12970   21907  ...   20250   41772   11923   19896   12689   11307
# 46   21684   21629  ...   44699   22956   15786   15353   11673   10832
# 47   11276    8947  ...   35438   15307   16425    8639   13840    6422
# 48   29184   50800  ...  112287  122168   78414   82361   68259   45958
# 49   39592   75160  ...  214091  250872  181154  180214  182745  109352
#
#     22시 승차  22시 하차  23시 승차  23시 하차
# 0   189168   53031  170213   45612
# 1    26477   47574   17539   44406
# 2    78492   64490   81124   58783
# 3    55463   25863   41846   23879
# 4    54718   87657   44059   86906
# 5    18985   44771   17463   43943
# 6    22043   53390   17007   53569
# 7    20299   33102   18199   31430
# 8    15037   48392   11720   47913
# 9      700    1612     373    1316
# 10   26636   22539   22420   21043
# 11   44627   13749   31321   12621
# 12   33544   21158   26602   19453
# 13   23109   17073   18052   16764
# 14   14653   44023   11797   41483
# 15   84775   70341   81584   67531
# 16  122207   16635   81515   12923
# 17   10975   24067    7955   22898
# 18   47663   83194   42918   81159
# 19   32784   12051   19871   11456
# 20   94775   22374   81769   19923
# 21   89282   19458   66587   16618
# 22   53011   10063   35289    8046
# 23     466    3873     448    3088
# 24   17894   22180   16955   20887
# 25   12944   58809   10695   57496
# 26   68585   72723   49959   71352
# 27   44191  117031   38470  112362
# 28    2655    3470    1859    3531
# 29    4993   20414    3720   18443
# 30   80782   44957   80890   39267
# 31    6884   17670    5546   17123
# 32    2604   14524    2098   12588
# 33   83807   20793   60134   18371
# 34   28589   21580   22738   20036
# 35   28936   20627   27857   19799
# 36    1411    6360    1188    6194
# 37    1651    3402    1107    2508
# 38   51897   14576   46357   12294
# 39   15558    9060   10709    8641
# 40  109010   29509   88711   22979
# 41   20648   23853   17042   24201
# 42  200008  104319  137183   94563
# 43    8142   18892    5955   18104
# 44   30027   36866   30123   34387
# 45   31072   11816   17348   11299
# 46   11394   11323    8428   10220
# 47   14908    6102   10879    5977
# 48   79171   38301   78470   34479
# 49  216017   91824  212376   75030
#
# [50 rows x 39 columns]

# %%
station_name = df_2023_station_title.loc[1,"지하철역"]

df_2022_one_station = df_2023.loc[df_2023["호선명"] == "2호선"]

df_2022_one_station = df_2022_one_station.loc[df_2023_one_station["지하철역"] == station_name]

df_2023_one_station.drop(columns = ["사용월", "호선명", "지하철역"], inplace = True)

df_2023_one_station.reset_index(drop = True, inplace = True)

element = len(df_2023_one_station)

station_name, element
# Out:
# ('강변(동서울터미널)', 12)

# %%
df_2023_one_station
# Out:
#     06시 승차  06시 하차  07시 승차  07시 하차  08시 승차  08시 하차  09시 승차  09시 하차  10시 승차  \
# 0     8316    1994   25176   19082   70058   21276  107811   40051   85444
# 1     9049    2026   28419   21267   80117   24773  120054   43777   89710
# 2     9106    2338   27634   25868   75208   27431  112407   43739   83962
# 3     8434    2370   26991   25205   72340   25865  109285   43527   81360
# 4     8883    2143   28090   22069   77944   24716  113417   44788   82099
# 5     8936    2251   28877   21987   78164   24402  117728   44028   82763
# 6     8913    2437   29088   23717   79276   25368  116728   44007   84484
# 7     8465    2474   28636   25628   79149   26677  120111   45600   87839
# 8     8244    2147   27075   23055   77066   24970  117351   43997   84314
# 9     8496    2230   28385   21622   84449   23122  127375   43433   89634
# 10    7696    2034   23866   18226   70316   20619  112239   39531   82142
# 11    7661    2128   23484   18515   69065   20650  107135   39991   77873
#
#     10시 하차  ...  19시 승차  19시 하차  20시 승차  20시 하차  21시 승차  21시 하차  22시 승차  \
# 0    35948  ...   60571  105525   42454   75080   32658   55641   26477
# 1    35919  ...   61011  113823   43199   78156   35293   53385   28286
# 2    37085  ...   60754  108425   46913   76514   39679   53542   33172
# 3    36495  ...   59392  105706   43782   74301   35356   51117   28629
# 4    38082  ...   60024  109698   42475   74212   34245   52055   28199
# 5    38028  ...   61291  109618   43557   76697   32792   53334   27539
# 6    36597  ...   61888  108453   43572   74887   34492   52461   28624
# 7    38589  ...   65031  111499   48613   79064   39132   54459   31419
# 8    37611  ...   61109  107895   44129   78057   35877   53687   28305
# 9    36312  ...   63523  115082   44985   83144   35564   55589   28249
# 10   34974  ...   57460  105988   40132   79306   32055   51495   25494
# 11   35752  ...   58548  103229   40165   74463   32638   49076   25722
#
#     22시 하차  23시 승차  23시 하차
# 0    47574   17539   44406
# 1    45226   17611   41842
# 2    45316   21736   40483
# 3    43706   18426   40220
# 4    42809   20093   41594
# 5    45308   19267   43488
# 6    45864   20387   43540
# 7    47811   22385   44739
# 8    44319   19259   41910
# 9    47508   18759   43630
# 10   43589   16448   39188
# 11   42222   17237   38243
#
# [12 rows x 36 columns]

# %%
df_2023_one_station.loc[element] = df_2023_one_station.mean(axis=0)

line_no = []
station_title = []
sixth = []
seventh = []
eighth = []
ninth = []
tenth = []
eleventh = []
twelveth = []
thirteenth = []
fourteenth = []
fifteenth = []
sixteenth = []
seventeenth = []
eighteenth = []
ninteenth = []
tewntieth = []
twentyfirst = []
twentysecond = []
twentythird = []


line_no.append(df_2023_line[1])
station_title.append(str(station_name))
sixth.append(int(df_2023_one_station.loc[element-1, "06시 승차"]) + int(df_2023_one_station.loc[element-1, "06시 하차"]))
seventh.append(int(df_2023_one_station.loc[element-1, "07시 승차"]) + int(df_2023_one_station.loc[element-1, "07시 하차"]))
eighth.append(int(df_2023_one_station.loc[element-1, "08시 승차"]) + int(df_2023_one_station.loc[element-1, "08시 하차"]))
ninth.append(int(df_2023_one_station.loc[element-1, "09시 승차"]) + int(df_2023_one_station.loc[element-1, "09시 하차"]))
tenth.append(int(df_2023_one_station.loc[element-1, "10시 승차"]) + int(df_2023_one_station.loc[element-1, "10시 하차"]))
eleventh.append(int(df_2023_one_station.loc[element-1, "11시 승차"]) + int(df_2023_one_station.loc[element-1, "11시 하차"]))
twelveth.append(int(df_2023_one_station.loc[element-1, "12시 승차"]) + int(df_2023_one_station.loc[element-1, "12시 하차"]))
thirteenth.append(int(df_2023_one_station.loc[element-1, "13시 승차"]) + int(df_2023_one_station.loc[element-1, "13시 하차"]))
fourteenth.append(int(df_2023_one_station.loc[element-1, "14시 승차"]) + int(df_2023_one_station.loc[element-1, "14시 하차"]))
fifteenth.append(int(df_2023_one_station.loc[element-1, "15시 승차"]) + int(df_2023_one_station.loc[element-1, "15시 하차"]))
sixteenth.append(int(df_2023_one_station.loc[element-1, "16시 승차"]) + int(df_2023_one_station.loc[element-1, "16시 하차"]))
seventeenth.append(int(df_2023_one_station.loc[element-1, "17시 승차"]) + int(df_2023_one_station.loc[element-1, "17시 하차"]))
eighteenth.append(int(df_2023_one_station.loc[element-1, "18시 승차"]) + int(df_2023_one_station.loc[element-1, "18시 하차"]))
ninteenth.append(int(df_2023_one_station.loc[element-1, "19시 승차"]) + int(df_2023_one_station.loc[element-1, "19시 하차"]))
tewntieth.append(int(df_2023_one_station.loc[element-1, "20시 승차"]) + int(df_2023_one_station.loc[element-1, "20시 하차"]))
twentyfirst.append(int(df_2023_one_station.loc[element-1, "21시 승차"]) + int(df_2023_one_station.loc[element-1, "21시 승차"]))
twentysecond.append(int(df_2023_one_station.loc[element-1, "22시 승차"]) + int(df_2023_one_station.loc[element-1, "22시 하차"]))
twentythird.append(int(df_2023_one_station.loc[element-1, "23시 승차"]) + int(df_2023_one_station.loc[element-1, "23시 하차"]))

#df_line1_2023_station

df_2023_total = {"호선명": line_no, "역명": station_title, "06시": sixth,\
                 "07시":seventh, "08시": eighth,\
                "09시":ninth, "10시":tenth,\
                "11시":eleventh, "12시":twelveth,\
                "13시":thirteenth, "14시":fourteenth,\
                "15시":fifteenth, "16시":sixteenth,\
                "17시":seventeenth, "18시":eighteenth,\
                "19시":ninteenth, "20시":tewntieth, "21시":twentyfirst,\
                "22시":twentysecond, "23시":twentythird}


print(df_2023_total)
# Out:
# {'호선명': ['2호선'], '역명': ['강변(동서울터미널)'], '06시': [9789], '07시': [41999], '08시': [89715], '09시': [147126], '10시': [113625], '11시': [97361], '12시': [89509], '13시': [91902], '14시': [94938], '15시': [96208], '16시': [104212], '17시': [112930], '18시': [130818], '19시': [161777], '20시': [114628], '21시': [65276], '22시': [67944], '23시': [55480]}

# %%
line_no = []
station_title = []
sixth = []
seventh = []
eighth = []
ninth = []
tenth = []
eleventh = []
twelveth = []
thirteenth = []
fourteenth = []
fifteenth = []
sixteenth = []
seventeenth = []
eighteenth = []
ninteenth = []
tewntieth = []
twentyfirst = []
twentysecond = []
twentythird = []

# %%
len(df_2023_station_title)
# Out:
# 10

# %%
for idx in range (0, len(df_2023_station_title), 1):
    station_name = df_2023_station.loc[idx,"지하철역"]
    print(station_name)
# Out:
# 동대문
# 동묘앞
# 서울역
# 시청
# 신설동
# 제기동
# 종각
# 종로3가
# 종로5가
# 청량리(서울시립대입구)

# %%
for idx_line in df_2023_line:

    df_2023_station_title = df_2023.loc[df_2023["사용월"] == 202312]

    df_2023_station_title = df_2023_station_title.loc[df_2023["호선명"] == idx_line]

    #df_2023_station = df_2023_station.loc[df_2023["지하철역"] == "동대문"]

    df_2023_station_title.reset_index(drop=True, inplace=True)

    df_2023_station_title

# %%
line_no = []
station_title = []
sixth = []
seventh = []
eighth = []
ninth = []
tenth = []
eleventh = []
twelveth = []
thirteenth = []
fourteenth = []
fifteenth = []
sixteenth = []
seventeenth = []
eighteenth = []
ninteenth = []
tewntieth = []
twentyfirst = []
twentysecond = []
twentythird = []

df_2023_line = ["1호선", "2호선", "3호선", "4호선", "5호선", "6호선", "7호선", "8호선"]


for idx_station in range (0, len(df_2023_station_title), 1):
    station_name = df_2023_station.loc[idx_station, "지하철역"]

    print(station_name)

    df_2023_one_station = df_2023.loc[df_2023["호선명"] == df_2023_line[0]]

    df_2023_one_station = df_2023_one_station.loc[df_2023_one_station["지하철역"] == station_name]

    df_2023_one_station.drop(columns = ["사용월", "호선명", "지하철역"], inplace = True)

    df_2023_one_station.reset_index(drop = True, inplace = True)

    element = len(df_2023_one_station)

    df_2023_one_station.loc[element] = df_2023_one_station.mean(axis=0)

    df_2023_one_station


    line_no.append(df_2023_line[0])
    station_title.append(str(station_name))
    sixth.append(int(df_2023_one_station.loc[element-1, "06시 승차"]) + int(df_2023_one_station.loc[element-1, "06시 하차"]))
    seventh.append(int(df_2023_one_station.loc[element-1, "07시 승차"]) + int(df_2023_one_station.loc[element-1, "07시 하차"]))
    eighth.append(int(df_2023_one_station.loc[element-1, "08시 승차"]) + int(df_2023_one_station.loc[element-1, "08시 하차"]))
    ninth.append(int(df_2023_one_station.loc[element-1, "09시 승차"]) + int(df_2023_one_station.loc[element-1, "09시 하차"]))
    tenth.append(int(df_2023_one_station.loc[element-1, "10시 승차"]) + int(df_2023_one_station.loc[element-1, "10시 하차"]))
    eleventh.append(int(df_2023_one_station.loc[element-1, "11시 승차"]) + int(df_2023_one_station.loc[element-1, "11시 하차"]))
    twelveth.append(int(df_2023_one_station.loc[element-1, "12시 승차"]) + int(df_2023_one_station.loc[element-1, "12시 하차"]))
    thirteenth.append(int(df_2023_one_station.loc[element-1, "13시 승차"]) + int(df_2023_one_station.loc[element-1, "13시 하차"]))
    fourteenth.append(int(df_2023_one_station.loc[element-1, "14시 승차"]) + int(df_2023_one_station.loc[element-1, "14시 하차"]))
    fifteenth.append(int(df_2023_one_station.loc[element-1, "15시 승차"]) + int(df_2023_one_station.loc[element-1, "15시 하차"]))
    sixteenth.append(int(df_2023_one_station.loc[element-1, "16시 승차"]) + int(df_2023_one_station.loc[element-1, "16시 하차"]))
    seventeenth.append(int(df_2023_one_station.loc[element-1, "17시 승차"]) + int(df_2023_one_station.loc[element-1, "17시 하차"]))
    eighteenth.append(int(df_2023_one_station.loc[element-1, "18시 승차"]) + int(df_2023_one_station.loc[element-1, "18시 하차"]))
    ninteenth.append(int(df_2023_one_station.loc[element-1, "19시 승차"]) + int(df_2023_one_station.loc[element-1, "19시 하차"]))
    tewntieth.append(int(df_2023_one_station.loc[element-1, "20시 승차"]) + int(df_2023_one_station.loc[element-1, "20시 하차"]))
    twentyfirst.append(int(df_2023_one_station.loc[element-1, "21시 승차"]) + int(df_2023_one_station.loc[element-1, "21시 승차"]))
    twentysecond.append(int(df_2023_one_station.loc[element-1, "22시 승차"]) + int(df_2023_one_station.loc[element-1, "22시 하차"]))
    twentythird.append(int(df_2023_one_station.loc[element-1, "23시 승차"]) + int(df_2023_one_station.loc[element-1, "23시 하차"]))

df_2023_total = {"호선명": line_no, "역명": station_title, "06시": sixth,\
                 "07시":seventh, "08시": eighth,\
                "09시":ninth, "10시":tenth,\
                "11시":eleventh, "12시":twelveth,\
                "13시":thirteenth, "14시":fourteenth,\
                "15시":fifteenth, "16시":sixteenth,\
                "17시":seventeenth, "18시":eighteenth,\
                "19시":ninteenth, "20시":tewntieth, "21시":twentyfirst,\
                "22시":twentysecond, "23시":twentythird}


print(df_2023_total)
# Out:
# 동대문
# 동묘앞
# 서울역
# 시청
# 신설동
# 제기동
# 종각
# 종로3가
# 종로5가
# 청량리(서울시립대입구)
# {'호선명': ['1호선', '1호선', '1호선', '1호선', '1호선', '1호선', '1호선', '1호선', '1호선', '1호선'], '역명': ['동대문', '동묘앞', '서울역', '시청', '신설동', '제기동', '종각', '종로3가', '종로5가', '청량리(서울시립대입구)'], '06시': [11190, 3358, 13990, 5856, 9530, 5908, 7901, 5965, 4673, 12261], '07시': [12877, 7307, 52859, 22443, 15027, 14075, 25214, 15032, 14105, 31734], '08시': [20197, 12120, 129585, 67360, 36825, 36474, 101745, 26406, 40798, 46788], '09시': [34191, 24016, 265248, 192501, 77257, 64450, 258294, 71625, 98315, 73226], '10시': [33805, 21734, 191913, 92053, 47193, 50132, 150629, 74909, 67064, 53244], '11시': [33944, 25416, 125908, 47941, 34667, 57768, 72656, 72241, 68113, 57811], '12시': [38914, 36277, 134271, 54538, 34674, 75298, 78810, 88969, 81812, 70359], '13시': [45042, 46878, 155381, 54277, 37204, 90000, 78382, 104664, 93753, 80443], '14시': [46117, 54744, 154009, 57486, 39523, 96221, 87431, 112090, 99142, 87688], '15시': [47490, 58229, 133509, 60602, 39307, 95733, 90425, 108485, 102156, 90584], '16시': [46898, 56147, 161585, 66873, 41188, 91976, 100272, 109637, 101322, 93536], '17시': [45366, 48969, 176419, 71422, 46266, 81648, 110539, 110638, 99702, 91921], '18시': [43532, 37361, 236816, 104950, 56647, 67508, 177147, 115957, 112968, 83313], '19시': [41134, 25077, 288749, 175739, 74450, 62658, 257080, 130171, 122725, 81485], '20시': [32754, 14362, 165631, 67952, 38427, 35964, 113141, 71594, 62701, 49195], '21시': [25336, 9488, 150624, 95058, 25804, 24670, 152136, 84832, 66040, 31604], '22시': [22636, 9366, 114133, 51872, 23758, 18779, 90213, 51677, 35884, 28923], '23시': [18361, 8460, 76219, 33430, 18700, 14506, 68700, 39409, 23390, 21232]}

# %%
df_year_data1 = [202312, 202212, 202112, 202012, 201912]
df_year_title = [2023, 2022, 2021, 2020, 2019]

df_2023 = df_line_all.loc[df_line_all["사용월"] >= 202301]
df_2023 = df_2023.loc[df_line_all["사용월"] <= 202312]
df_2023.reset_index(drop = True, inplace = True)

df_2022 = df_line_all.loc[df_line_all["사용월"] >= 202201]
df_2022 = df_2022.loc[df_line_all["사용월"] <= 202212]
df_2022.reset_index(drop = True, inplace = True)

df_2021 = df_line_all.loc[df_line_all["사용월"] >= 202101]
df_2021 = df_2021.loc[df_line_all["사용월"] <= 202112]
df_2021.reset_index(drop = True, inplace = True)

df_2020 = df_line_all.loc[df_line_all["사용월"] >= 202001]
df_2020 = df_2020.loc[df_line_all["사용월"] <= 202012]
df_2020.reset_index(drop = True, inplace = True)

df_2019 = df_line_all.loc[df_line_all["사용월"] >= 201901]
df_2019 = df_2019.loc[df_line_all["사용월"] <= 201912]
df_2019.reset_index(drop = True, inplace = True)

year = []
line_no = []
station_title = []
sixth = []
seventh = []
eighth = []
ninth = []
tenth = []
eleventh = []
twelveth = []
thirteenth = []
fourteenth = []
fifteenth = []
sixteenth = []
seventeenth = []
eighteenth = []
ninteenth = []
tewntieth = []
twentyfirst = []
twentysecond = []
twentythird = []

df_line = ["1호선", "2호선", "3호선", "4호선", "5호선", "6호선", "7호선", "8호선"]


for idx_line in df_line:

    print(idx_line)

    df_station_title = df_2023.loc[df_2023["사용월"] == df_year_data1[0]]

    df_station_title = df_station_title.loc[df_2023["호선명"] == idx_line]

    df_station_title.reset_index(drop=True, inplace=True)

    df_station_title

    for idx_station in range (0, len(df_station_title), 1):
        station_name = df_station_title.loc[idx_station, "지하철역"]

        print(station_name)

        df_2023_one_station = df_2023.loc[df_2023["호선명"] == idx_line]

        df_2023_one_station = df_2023_one_station.loc[df_2023_one_station["지하철역"] == station_name]

        df_2023_one_station.drop(columns = ["사용월", "호선명", "지하철역"], inplace = True)

        df_2023_one_station.reset_index(drop = True, inplace = True)

        element = len(df_2023_one_station)

        df_2023_one_station.loc[element] = df_2023_one_station.mean(axis=0)

        df_2023_one_station

        year.append(df_year_title[0])
        line_no.append(idx_line)
        station_title.append(str(station_name))
        sixth.append(int(df_2023_one_station.loc[element-1, "06시 승차"]) + int(df_2023_one_station.loc[element-1, "06시 하차"]))
        seventh.append(int(df_2023_one_station.loc[element-1, "07시 승차"]) + int(df_2023_one_station.loc[element-1, "07시 하차"]))
        eighth.append(int(df_2023_one_station.loc[element-1, "08시 승차"]) + int(df_2023_one_station.loc[element-1, "08시 하차"]))
        ninth.append(int(df_2023_one_station.loc[element-1, "09시 승차"]) + int(df_2023_one_station.loc[element-1, "09시 하차"]))
        tenth.append(int(df_2023_one_station.loc[element-1, "10시 승차"]) + int(df_2023_one_station.loc[element-1, "10시 하차"]))
        eleventh.append(int(df_2023_one_station.loc[element-1, "11시 승차"]) + int(df_2023_one_station.loc[element-1, "11시 하차"]))
        twelveth.append(int(df_2023_one_station.loc[element-1, "12시 승차"]) + int(df_2023_one_station.loc[element-1, "12시 하차"]))
        thirteenth.append(int(df_2023_one_station.loc[element-1, "13시 승차"]) + int(df_2023_one_station.loc[element-1, "13시 하차"]))
        fourteenth.append(int(df_2023_one_station.loc[element-1, "14시 승차"]) + int(df_2023_one_station.loc[element-1, "14시 하차"]))
        fifteenth.append(int(df_2023_one_station.loc[element-1, "15시 승차"]) + int(df_2023_one_station.loc[element-1, "15시 하차"]))
        sixteenth.append(int(df_2023_one_station.loc[element-1, "16시 승차"]) + int(df_2023_one_station.loc[element-1, "16시 하차"]))
        seventeenth.append(int(df_2023_one_station.loc[element-1, "17시 승차"]) + int(df_2023_one_station.loc[element-1, "17시 하차"]))
        eighteenth.append(int(df_2023_one_station.loc[element-1, "18시 승차"]) + int(df_2023_one_station.loc[element-1, "18시 하차"]))
        ninteenth.append(int(df_2023_one_station.loc[element-1, "19시 승차"]) + int(df_2023_one_station.loc[element-1, "19시 하차"]))
        tewntieth.append(int(df_2023_one_station.loc[element-1, "20시 승차"]) + int(df_2023_one_station.loc[element-1, "20시 하차"]))
        twentyfirst.append(int(df_2023_one_station.loc[element-1, "21시 승차"]) + int(df_2023_one_station.loc[element-1, "21시 승차"]))
        twentysecond.append(int(df_2023_one_station.loc[element-1, "22시 승차"]) + int(df_2023_one_station.loc[element-1, "22시 하차"]))
        twentythird.append(int(df_2023_one_station.loc[element-1, "23시 승차"]) + int(df_2023_one_station.loc[element-1, "23시 하차"]))
        

for idx_line in df_line:

    print(idx_line)

    df_station_title = df_2022.loc[df_2022["사용월"] == df_year_data1[1]]

    df_station_title = df_station_title.loc[df_2022["호선명"] == idx_line]

    df_station_title.reset_index(drop=True, inplace=True)

    df_station_title

    for idx_station in range (0, len(df_station_title), 1):
        station_name = df_station_title.loc[idx_station, "지하철역"]

        print(station_name)

        df_2022_one_station = df_2022.loc[df_2022["호선명"] == idx_line]

        df_2022_one_station = df_2022_one_station.loc[df_2022_one_station["지하철역"] == station_name]

        df_2022_one_station.drop(columns = ["사용월", "호선명", "지하철역"], inplace = True)

        df_2022_one_station.reset_index(drop = True, inplace = True)

        element = len(df_2022_one_station)

        df_2022_one_station.loc[element] = df_2022_one_station.mean(axis=0)

        df_2022_one_station

        year.append(df_year_title[1])
        line_no.append(idx_line)
        station_title.append(str(station_name))
        sixth.append(int(df_2022_one_station.loc[element-1, "06시 승차"]) + int(df_2022_one_station.loc[element-1, "06시 하차"]))
        seventh.append(int(df_2022_one_station.loc[element-1, "07시 승차"]) + int(df_2022_one_station.loc[element-1, "07시 하차"]))
        eighth.append(int(df_2022_one_station.loc[element-1, "08시 승차"]) + int(df_2022_one_station.loc[element-1, "08시 하차"]))
        ninth.append(int(df_2022_one_station.loc[element-1, "09시 승차"]) + int(df_2022_one_station.loc[element-1, "09시 하차"]))
        tenth.append(int(df_2022_one_station.loc[element-1, "10시 승차"]) + int(df_2022_one_station.loc[element-1, "10시 하차"]))
        eleventh.append(int(df_2022_one_station.loc[element-1, "11시 승차"]) + int(df_2022_one_station.loc[element-1, "11시 하차"]))
        twelveth.append(int(df_2022_one_station.loc[element-1, "12시 승차"]) + int(df_2022_one_station.loc[element-1, "12시 하차"]))
        thirteenth.append(int(df_2022_one_station.loc[element-1, "13시 승차"]) + int(df_2022_one_station.loc[element-1, "13시 하차"]))
        fourteenth.append(int(df_2022_one_station.loc[element-1, "14시 승차"]) + int(df_2022_one_station.loc[element-1, "14시 하차"]))
        fifteenth.append(int(df_2022_one_station.loc[element-1, "15시 승차"]) + int(df_2022_one_station.loc[element-1, "15시 하차"]))
        sixteenth.append(int(df_2022_one_station.loc[element-1, "16시 승차"]) + int(df_2022_one_station.loc[element-1, "16시 하차"]))
        seventeenth.append(int(df_2022_one_station.loc[element-1, "17시 승차"]) + int(df_2022_one_station.loc[element-1, "17시 하차"]))
        eighteenth.append(int(df_2022_one_station.loc[element-1, "18시 승차"]) + int(df_2022_one_station.loc[element-1, "18시 하차"]))
        ninteenth.append(int(df_2022_one_station.loc[element-1, "19시 승차"]) + int(df_2022_one_station.loc[element-1, "19시 하차"]))
        tewntieth.append(int(df_2022_one_station.loc[element-1, "20시 승차"]) + int(df_2022_one_station.loc[element-1, "20시 하차"]))
        twentyfirst.append(int(df_2022_one_station.loc[element-1, "21시 승차"]) + int(df_2022_one_station.loc[element-1, "21시 승차"]))
        twentysecond.append(int(df_2022_one_station.loc[element-1, "22시 승차"]) + int(df_2022_one_station.loc[element-1, "22시 하차"]))
        twentythird.append(int(df_2022_one_station.loc[element-1, "23시 승차"]) + int(df_2022_one_station.loc[element-1, "23시 하차"]))

for idx_line in df_line:

    print(idx_line)

    df_station_title = df_2021.loc[df_2021["사용월"] == df_year_data1[1]]

    df_station_title = df_station_title.loc[df_2021["호선명"] == idx_line]

    df_station_title.reset_index(drop=True, inplace=True)

    df_station_title

    for idx_station in range (0, len(df_station_title), 1):
        station_name = df_station_title.loc[idx_station, "지하철역"]

        print(station_name)

        df_2021_one_station = df_2021.loc[df_2021["호선명"] == idx_line]

        df_2021_one_station = df_2021_one_station.loc[df_2021_one_station["지하철역"] == station_name]

        df_2021_one_station.drop(columns = ["사용월", "호선명", "지하철역"], inplace = True)

        df_2021_one_station.reset_index(drop = True, inplace = True)

        element = len(df_2021_one_station)

        df_2021_one_station.loc[element] = df_2021_one_station.mean(axis=0)

        df_2021_one_station

        year.append(df_year_title[1])
        line_no.append(idx_line)
        station_title.append(str(station_name))
        sixth.append(int(df_2021_one_station.loc[element-1, "06시 승차"]) + int(df_2021_one_station.loc[element-1, "06시 하차"]))
        seventh.append(int(df_2021_one_station.loc[element-1, "07시 승차"]) + int(df_2021_one_station.loc[element-1, "07시 하차"]))
        eighth.append(int(df_2021_one_station.loc[element-1, "08시 승차"]) + int(df_2021_one_station.loc[element-1, "08시 하차"]))
        ninth.append(int(df_2021_one_station.loc[element-1, "09시 승차"]) + int(df_2021_one_station.loc[element-1, "09시 하차"]))
        tenth.append(int(df_2021_one_station.loc[element-1, "10시 승차"]) + int(df_2021_one_station.loc[element-1, "10시 하차"]))
        eleventh.append(int(df_2021_one_station.loc[element-1, "11시 승차"]) + int(df_2021_one_station.loc[element-1, "11시 하차"]))
        twelveth.append(int(df_2021_one_station.loc[element-1, "12시 승차"]) + int(df_2021_one_station.loc[element-1, "12시 하차"]))
        thirteenth.append(int(df_2021_one_station.loc[element-1, "13시 승차"]) + int(df_2021_one_station.loc[element-1, "13시 하차"]))
        fourteenth.append(int(df_2021_one_station.loc[element-1, "14시 승차"]) + int(df_2021_one_station.loc[element-1, "14시 하차"]))
        fifteenth.append(int(df_2021_one_station.loc[element-1, "15시 승차"]) + int(df_2021_one_station.loc[element-1, "15시 하차"]))
        sixteenth.append(int(df_2021_one_station.loc[element-1, "16시 승차"]) + int(df_2021_one_station.loc[element-1, "16시 하차"]))
        seventeenth.append(int(df_2021_one_station.loc[element-1, "17시 승차"]) + int(df_2021_one_station.loc[element-1, "17시 하차"]))
        eighteenth.append(int(df_2021_one_station.loc[element-1, "18시 승차"]) + int(df_2021_one_station.loc[element-1, "18시 하차"]))
        ninteenth.append(int(df_2021_one_station.loc[element-1, "19시 승차"]) + int(df_2021_one_station.loc[element-1, "19시 하차"]))
        tewntieth.append(int(df_2021_one_station.loc[element-1, "20시 승차"]) + int(df_2021_one_station.loc[element-1, "20시 하차"]))
        twentyfirst.append(int(df_2021_one_station.loc[element-1, "21시 승차"]) + int(df_2021_one_station.loc[element-1, "21시 승차"]))
        twentysecond.append(int(df_2021_one_station.loc[element-1, "22시 승차"]) + int(df_2021_one_station.loc[element-1, "22시 하차"]))
        twentythird.append(int(df_2021_one_station.loc[element-1, "23시 승차"]) + int(df_2021_one_station.loc[element-1, "23시 하차"]))

for idx_line in df_line:

    print(idx_line)

    df_station_title = df_2020.loc[df_2020["사용월"] == df_year_data1[1]]

    df_station_title = df_station_title.loc[df_2020["호선명"] == idx_line]

    df_station_title.reset_index(drop=True, inplace=True)

    df_station_title

    for idx_station in range (0, len(df_station_title), 1):
        station_name = df_station_title.loc[idx_station, "지하철역"]

        print(station_name)

        df_2020_one_station = df_2020.loc[df_2020["호선명"] == idx_line]

        df_2020_one_station = df_2020_one_station.loc[df_2020_one_station["지하철역"] == station_name]

        df_2020_one_station.drop(columns = ["사용월", "호선명", "지하철역"], inplace = True)

        df_2020_one_station.reset_index(drop = True, inplace = True)

        element = len(df_2020_one_station)

        df_2020_one_station.loc[element] = df_2020_one_station.mean(axis=0)

        df_2020_one_station

        year.append(df_year_title[1])
        line_no.append(idx_line)
        station_title.append(str(station_name))
        sixth.append(int(df_2020_one_station.loc[element-1, "06시 승차"]) + int(df_2020_one_station.loc[element-1, "06시 하차"]))
        seventh.append(int(df_2020_one_station.loc[element-1, "07시 승차"]) + int(df_2020_one_station.loc[element-1, "07시 하차"]))
        eighth.append(int(df_2020_one_station.loc[element-1, "08시 승차"]) + int(df_2020_one_station.loc[element-1, "08시 하차"]))
        ninth.append(int(df_2020_one_station.loc[element-1, "09시 승차"]) + int(df_2020_one_station.loc[element-1, "09시 하차"]))
        tenth.append(int(df_2020_one_station.loc[element-1, "10시 승차"]) + int(df_2020_one_station.loc[element-1, "10시 하차"]))
        eleventh.append(int(df_2020_one_station.loc[element-1, "11시 승차"]) + int(df_2020_one_station.loc[element-1, "11시 하차"]))
        twelveth.append(int(df_2020_one_station.loc[element-1, "12시 승차"]) + int(df_2020_one_station.loc[element-1, "12시 하차"]))
        thirteenth.append(int(df_2020_one_station.loc[element-1, "13시 승차"]) + int(df_2020_one_station.loc[element-1, "13시 하차"]))
        fourteenth.append(int(df_2020_one_station.loc[element-1, "14시 승차"]) + int(df_2020_one_station.loc[element-1, "14시 하차"]))
        fifteenth.append(int(df_2020_one_station.loc[element-1, "15시 승차"]) + int(df_2020_one_station.loc[element-1, "15시 하차"]))
        sixteenth.append(int(df_2020_one_station.loc[element-1, "16시 승차"]) + int(df_2020_one_station.loc[element-1, "16시 하차"]))
        seventeenth.append(int(df_2020_one_station.loc[element-1, "17시 승차"]) + int(df_2020_one_station.loc[element-1, "17시 하차"]))
        eighteenth.append(int(df_2020_one_station.loc[element-1, "18시 승차"]) + int(df_2020_one_station.loc[element-1, "18시 하차"]))
        ninteenth.append(int(df_2020_one_station.loc[element-1, "19시 승차"]) + int(df_2020_one_station.loc[element-1, "19시 하차"]))
        tewntieth.append(int(df_2020_one_station.loc[element-1, "20시 승차"]) + int(df_2020_one_station.loc[element-1, "20시 하차"]))
        twentyfirst.append(int(df_2020_one_station.loc[element-1, "21시 승차"]) + int(df_2020_one_station.loc[element-1, "21시 승차"]))
        twentysecond.append(int(df_2020_one_station.loc[element-1, "22시 승차"]) + int(df_2020_one_station.loc[element-1, "22시 하차"]))
        twentythird.append(int(df_2020_one_station.loc[element-1, "23시 승차"]) + int(df_2020_one_station.loc[element-1, "23시 하차"]))

for idx_line in df_line:

    print(idx_line)

    df_station_title = df_2019.loc[df_2019["사용월"] == df_year_data1[1]]

    df_station_title = df_station_title.loc[df_2019["호선명"] == idx_line]

    df_station_title.reset_index(drop=True, inplace=True)

    df_station_title

    for idx_station in range (0, len(df_station_title), 1):
        station_name = df_station_title.loc[idx_station, "지하철역"]

        print(station_name)

        df_2019_one_station = df_2019.loc[df_2019["호선명"] == idx_line]

        df_2019_one_station = df_2019_one_station.loc[df_2019_one_station["지하철역"] == station_name]

        df_2019_one_station.drop(columns = ["사용월", "호선명", "지하철역"], inplace = True)

        df_2019_one_station.reset_index(drop = True, inplace = True)

        element = len(df_2019_one_station)

        df_2019_one_station.loc[element] = df_2019_one_station.mean(axis=0)

        df_2019_one_station

        year.append(df_year_title[1])
        line_no.append(idx_line)
        station_title.append(str(station_name))
        sixth.append(int(df_2019_one_station.loc[element-1, "06시 승차"]) + int(df_2019_one_station.loc[element-1, "06시 하차"]))
        seventh.append(int(df_2019_one_station.loc[element-1, "07시 승차"]) + int(df_2019_one_station.loc[element-1, "07시 하차"]))
        eighth.append(int(df_2019_one_station.loc[element-1, "08시 승차"]) + int(df_2019_one_station.loc[element-1, "08시 하차"]))
        ninth.append(int(df_2019_one_station.loc[element-1, "09시 승차"]) + int(df_2019_one_station.loc[element-1, "09시 하차"]))
        tenth.append(int(df_2019_one_station.loc[element-1, "10시 승차"]) + int(df_2019_one_station.loc[element-1, "10시 하차"]))
        eleventh.append(int(df_2019_one_station.loc[element-1, "11시 승차"]) + int(df_2019_one_station.loc[element-1, "11시 하차"]))
        twelveth.append(int(df_2019_one_station.loc[element-1, "12시 승차"]) + int(df_2019_one_station.loc[element-1, "12시 하차"]))
        thirteenth.append(int(df_2019_one_station.loc[element-1, "13시 승차"]) + int(df_2019_one_station.loc[element-1, "13시 하차"]))
        fourteenth.append(int(df_2019_one_station.loc[element-1, "14시 승차"]) + int(df_2019_one_station.loc[element-1, "14시 하차"]))
        fifteenth.append(int(df_2019_one_station.loc[element-1, "15시 승차"]) + int(df_2019_one_station.loc[element-1, "15시 하차"]))
        sixteenth.append(int(df_2019_one_station.loc[element-1, "16시 승차"]) + int(df_2019_one_station.loc[element-1, "16시 하차"]))
        seventeenth.append(int(df_2019_one_station.loc[element-1, "17시 승차"]) + int(df_2019_one_station.loc[element-1, "17시 하차"]))
        eighteenth.append(int(df_2019_one_station.loc[element-1, "18시 승차"]) + int(df_2019_one_station.loc[element-1, "18시 하차"]))
        ninteenth.append(int(df_2019_one_station.loc[element-1, "19시 승차"]) + int(df_2019_one_station.loc[element-1, "19시 하차"]))
        tewntieth.append(int(df_2019_one_station.loc[element-1, "20시 승차"]) + int(df_2019_one_station.loc[element-1, "20시 하차"]))
        twentyfirst.append(int(df_2019_one_station.loc[element-1, "21시 승차"]) + int(df_2019_one_station.loc[element-1, "21시 승차"]))
        twentysecond.append(int(df_2019_one_station.loc[element-1, "22시 승차"]) + int(df_2019_one_station.loc[element-1, "22시 하차"]))
        twentythird.append(int(df_2019_one_station.loc[element-1, "23시 승차"]) + int(df_2019_one_station.loc[element-1, "23시 하차"]))
        

df_total = {"조사연도": year, "호선명": line_no, "역명": station_title, "06시": sixth,\
                 "07시":seventh, "08시": eighth,\
                "09시":ninth, "10시":tenth,\
                "11시":eleventh, "12시":twelveth,\
                "13시":thirteenth, "14시":fourteenth,\
                "15시":fifteenth, "16시":sixteenth,\
                "17시":seventeenth, "18시":eighteenth,\
                "19시":ninteenth, "20시":tewntieth, "21시":twentyfirst,\
                "22시":twentysecond, "23시":twentythird}


print(df_total)
# Out:
# 1호선
# 동대문
# 동묘앞
# 서울역
# 시청
# 신설동
# 제기동
# 종각
# 종로3가
# 종로5가
# 청량리(서울시립대입구)
# 2호선
# 강남
# 강변(동서울터미널)
# 건대입구
# 교대(법원.검찰청)
# 구로디지털단지
# 구의(광진구청)
# 낙성대(강감찬)
# 당산
# 대림(구로구청)
# 도림천
# 동대문역사문화공원(DDP)
# 뚝섬
# 문래
# 방배
# 봉천
# 사당
# 삼성(무역센터)
# 상왕십리
# 서울대입구(관악구청)
# 서초
# 선릉
# 성수
# 시청
# 신답
# 신당
# 신대방
# 신도림
# 신림
# 신설동
# 신정네거리
# 신촌
# 아현
# 양천구청
# 역삼
# 영등포구청
# 왕십리(성동구청)
# 용답
# 용두(동대문구청)
# 을지로3가
# 을지로4가
# 을지로입구
# 이대
# 잠실(송파구청)
# 잠실나루
# 잠실새내
# 종합운동장
# 충정로(경기대입구)
# 한양대
# 합정
# 홍대입구
# 3호선
# 가락시장
# 경복궁(정부서울청사)
# 경찰병원
# 고속터미널
# 교대(법원.검찰청)
# 구파발
# 금호
# 남부터미널(예술의전당)
# 녹번
# 대청
# 대치
# 도곡
# 독립문
# 동대입구
# 매봉
# 무악재
# 불광
# 수서
# 신사
# 안국
# 압구정
# 약수
# 양재(서초구청)
# 연신내
# 오금
# 옥수
# 을지로3가
# 일원
# 잠원
# 종로3가
# 지축
# 충무로
# 학여울
# 홍제
# 4호선
# 길음
# 남태령
# 노원
# 당고개
# 동대문
# 동대문역사문화공원(DDP)
# 동작(현충원)
# 명동
# 미아(서울사이버대학)
# 미아사거리
# 사당
# 삼각지
# 상계
# 서울역
# 성신여대입구(돈암)
# 수유(강북구청)
# 숙대입구(갈월)
# 신용산
# 쌍문
# 이촌(국립중앙박물관)
# 창동
# 총신대입구(이수)
# 충무로
# 한성대입구(삼선교)
# 혜화
# 회현(남대문시장)
# 5호선
# 강동
# 강일
# 개롱
# 개화산
# 거여
# 고덕
# 공덕
# 광나루(장신대)
# 광화문(세종문화회관)
# 군자(능동)
# 굽은다리(강동구민회관앞)
# 길동
# 김포공항
# 까치산
# 답십리
# 동대문역사문화공원(DDP)
# 둔촌동
# 마곡
# 마장
# 마천
# 마포
# 명일
# 목동
# 미사
# 발산
# 방이
# 방화
# 상일동
# 서대문
# 송정
# 신금호
# 신길
# 신정(은행정)
# 아차산(어린이대공원후문)
# 애오개
# 양평
# 여의나루
# 여의도
# 영등포구청
# 영등포시장
# 오금
# 오목교(목동운동장앞)
# 올림픽공원(한국체대)
# 왕십리(성동구청)
# 우장산
# 을지로4가
# 장한평
# 종로3가
# 천호(풍납토성)
# 청구
# 충정로(경기대입구)
# 하남검단산
# 하남시청(덕풍?신장)
# 하남풍산
# 행당
# 화곡
# 6호선
# 고려대(종암)
# 공덕
# 광흥창(서강)
# 구산
# 녹사평(용산구청)
# 대흥(서강대앞)
# 독바위
# 돌곶이
# 동묘앞
# 디지털미디어시티
# 마포구청
# 망원
# 버티고개
# 보문
# 봉화산(서울의료원)
# 불광
# 삼각지
# 상수
# 상월곡(한국과학기술연구원)
# 새절(신사)
# 석계
# 신내
# 신당
# 안암(고대병원앞)
# 약수
# 역촌
# 연신내
# 월곡(동덕여대)
# 월드컵경기장(성산)
# 응암
# 이태원
# 증산(명지대앞)
# 창신
# 청구
# 태릉입구
# 한강진
# 합정
# 화랑대(서울여대입구)
# 효창공원앞
# 7호선
# 가산디지털단지
# 강남구청
# 건대입구
# 고속터미널
# 공릉(서울과학기술대)
# 광명사거리
# 군자(능동)
# 굴포천
# 남구로
# 남성
# 내방
# 노원
# 논현
# 대림(구로구청)
# 도봉산
# 뚝섬유원지
# 마들
# 먹골
# 면목
# 반포
# 보라매
# 사가정
# 상도
# 상봉(시외버스터미널)
# 수락산
# 숭실대입구(살피재)
# 신대방삼거리
# 신중동
# 신풍
# 어린이대공원(세종대)
# 온수(성공회대입구)
# 용마산(용마폭포공원)
# 이수
# 장승배기
# 장암
# 중계
# 중곡
# 중화
# 천왕
# 철산
# 청담
# 춘의
# 태릉입구
# 하계
# 학동
# 8호선
# 가락시장
# 강동구청
# 남위례
# 남한산성입구(성남법원.검찰청)
# 단대오거리
# 모란
# 몽촌토성(평화의문)
# 문정
# 복정
# 산성
# 석촌
# 송파
# 수진
# 신흥
# 암사
# 잠실(송파구청)
# 장지
# 천호(풍납토성)
# 1호선
# 동대문
# 동묘앞
# 서울역
# 시청
# 신설동
# 제기동
# 종각
# 종로3가
# 종로5가
# 청량리(서울시립대입구)
# 2호선
# 강남
# 강변(동서울터미널)
# 건대입구
# 교대(법원.검찰청)
# 구로디지털단지
# 구의(광진구청)
# 낙성대(강감찬)
# 당산
# 대림(구로구청)
# 도림천
# 동대문역사문화공원(DDP)
# 뚝섬
# 문래
# 방배
# 봉천
# 사당
# 삼성(무역센터)
# 상왕십리
# 서울대입구(관악구청)
# 서초
# 선릉
# 성수
# 시청
# 신답
# 신당
# 신대방
# 신도림
# 신림
# 신설동
# 신정네거리
# 신촌
# 아현
# 양천구청
# 역삼
# 영등포구청
# 왕십리(성동구청)
# 용답
# 용두(동대문구청)
# 을지로3가
# 을지로4가
# 을지로입구
# 이대
# 잠실(송파구청)
# 잠실나루
# 잠실새내
# 종합운동장
# 충정로(경기대입구)
# 한양대
# 합정
# 홍대입구
# 3호선
# 가락시장
# 경복궁(정부서울청사)
# 경찰병원
# 고속터미널
# 교대(법원.검찰청)
# 구파발
# 금호
# 남부터미널(예술의전당)
# 녹번
# 대청
# 대치
# 도곡
# 독립문
# 동대입구
# 매봉
# 무악재
# 불광
# 수서
# 신사
# 안국
# 압구정
# 약수
# 양재(서초구청)
# 연신내
# 오금
# 옥수
# 을지로3가
# 일원
# 잠원
# 종로3가
# 지축
# 충무로
# 학여울
# 홍제
# 4호선
# 길음
# 남태령
# 노원
# 당고개
# 동대문
# 동대문역사문화공원(DDP)
# 동작(현충원)
# 명동
# 미아(서울사이버대학)
# 미아사거리
# 사당
# 삼각지
# 상계
# 서울역
# 성신여대입구(돈암)
# 수유(강북구청)
# 숙대입구(갈월)
# 신용산
# 쌍문
# 이촌(국립중앙박물관)
# 창동
# 총신대입구(이수)
# 충무로
# 한성대입구(삼선교)
# 혜화
# 회현(남대문시장)
# 5호선
# 강동
# 강일
# 개롱
# 개화산
# 거여
# 고덕
# 공덕
# 광나루(장신대)
# 광화문(세종문화회관)
# 군자(능동)
# 굽은다리(강동구민회관앞)
# 길동
# 김포공항
# 까치산
# 답십리
# 동대문역사문화공원(DDP)
# 둔촌동
# 마곡
# 마장
# 마천
# 마포
# 명일
# 목동
# 미사
# 발산
# 방이
# 방화
# 상일동
# 서대문
# 송정
# 신금호
# 신길
# 신정(은행정)
# 아차산(어린이대공원후문)
# 애오개
# 양평
# 여의나루
# 여의도
# 영등포구청
# 영등포시장
# 오금
# 오목교(목동운동장앞)
# 올림픽공원(한국체대)
# 왕십리(성동구청)
# 우장산
# 을지로4가
# 장한평
# 종로3가
# 천호(풍납토성)
# 청구
# 충정로(경기대입구)
# 하남검단산
# 하남시청(덕풍?신장)
# 하남풍산
# 행당
# 화곡
# 6호선
# 고려대(종암)
# 공덕
# 광흥창(서강)
# 구산
# 녹사평(용산구청)
# 대흥(서강대앞)
# 독바위
# 돌곶이
# 동묘앞
# 디지털미디어시티
# 마포구청
# 망원
# 버티고개
# 보문
# 봉화산(서울의료원)
# 불광
# 삼각지
# 상수
# 상월곡(한국과학기술연구원)
# 새절(신사)
# 석계
# 신내
# 신당
# 안암(고대병원앞)
# 약수
# 역촌
# 연신내
# 월곡(동덕여대)
# 월드컵경기장(성산)
# 응암
# 이태원
# 증산(명지대앞)
# 창신
# 청구
# 태릉입구
# 한강진
# 합정
# 화랑대(서울여대입구)
# 효창공원앞
# 7호선
# 가산디지털단지
# 강남구청
# 건대입구
# 고속터미널
# 공릉(서울과학기술대)
# 광명사거리
# 군자(능동)
# 남구로
# 남성
# 내방
# 노원
# 논현
# 대림(구로구청)
# 도봉산
# 뚝섬유원지
# 마들
# 먹골
# 면목
# 반포
# 보라매
# 사가정
# 상도
# 상봉(시외버스터미널)
# 수락산
# 숭실대입구(살피재)
# 신대방삼거리
# 신풍
# 어린이대공원(세종대)
# 온수(성공회대입구)
# 용마산(용마폭포공원)
# 이수
# 장승배기
# 장암
# 중계
# 중곡
# 중화
# 천왕
# 철산
# 청담
# 태릉입구
# 하계
# 학동
# 8호선
# 가락시장
# 강동구청
# 남위례
# 남한산성입구(성남법원.검찰청)
# 단대오거리
# 모란
# 몽촌토성(평화의문)
# 문정
# 복정
# 산성
# 석촌
# 송파
# 수진
# 신흥
# 암사
# 잠실(송파구청)
# 장지
# 천호(풍납토성)
# 1호선
# 2호선
# 3호선
# 4호선
# 5호선
# 6호선
# 7호선
# 8호선
# 1호선
# 2호선
# 3호선
# 4호선
# 5호선
# 6호선
# 7호선
# 8호선
# 1호선
# 2호선
# 3호선
# 4호선
# 5호선
# 6호선
# 7호선
# 8호선
# {'조사연도': [2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022], '호선명': ['1호선', '1호선', '1호선', '1호선', '1호선', '1호선', '1호선', '1호선', '1호선', '1호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '2호선', '3호선', '3호선', '3호선', '3호선', '3호선', '3호선', '3호선', '3호선', '3호선', '3호선', '3호선', '3호선', '3호선', '3호선', '3호선', '3호선', '3호선', '3호선', '3호선', '3호선', '3호선', '3호선', '3호선', '3호선', '3호선', '3호선', '3호선', '3호선', '3호선', '3호선', '3호선', '3호선', '3호선', '3호선', '4호선' ...

# %%
# Out:
# {'호선명': ['1호선', '1호선', '1호선', '1호선', '1호선', '1호선', '1호선', '1호선', '1호선', '1호선', '2호선'], '역명': ['동대문', '동묘앞', '서울역', '시청', '신설동', '제기동', '종각', '종로3가', '종로5가', '청량리(서울시립대입구)', '동대문'], '06시': [11190, 3358, 13990, 5856, 9530, 5908, 7901, 5965, 4673, 12261], '07시': [12877, 7307, 52859, 22443, 15027, 14075, 25214, 15032, 14105, 31734], '08시': [20197, 12120, 129585, 67360, 36825, 36474, 101745, 26406, 40798, 46788], '09시': [34191, 24016, 265248, 192501, 77257, 64450, 258294, 71625, 98315, 73226], '10시': [33805, 21734, 191913, 92053, 47193, 50132, 150629, 74909, 67064, 53244], '11시': [33944, 25416, 125908, 47941, 34667, 57768, 72656, 72241, 68113, 57811], '12시': [38914, 36277, 134271, 54538, 34674, 75298, 78810, 88969, 81812, 70359], '13시': [45042, 46878, 155381, 54277, 37204, 90000, 78382, 104664, 93753, 80443], '14시': [46117, 54744, 154009, 57486, 39523, 96221, 87431, 112090, 99142, 87688], '15시': [47490, 58229, 133509, 60602, 39307, 95733, 90425, 108485, 102156, 90584], '16시': [46898, 56147, 161585, 66873, 41188, 91976, 100272, 109637, 101322, 93536], '17시': [45366, 48969, 176419, 71422, 46266, 81648, 110539, 110638, 99702, 91921], '18시': [43532, 37361, 236816, 104950, 56647, 67508, 177147, 115957, 112968, 83313], '19시': [41134, 25077, 288749, 175739, 74450, 62658, 257080, 130171, 122725, 81485], '20시': [32754, 14362, 165631, 67952, 38427, 35964, 113141, 71594, 62701, 49195], '21시': [25336, 9488, 150624, 95058, 25804, 24670, 152136, 84832, 66040, 31604], '22시': [22636, 9366, 114133, 51872, 23758, 18779, 90213, 51677, 35884, 28923], '23시': [18361, 8460, 76219, 33430, 18700, 14506, 68700, 39409, 23390, 21232]}
